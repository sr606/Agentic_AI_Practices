# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/Agentic_AI_Practices/blob/main/Lineage_Diagrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import graphviz

dot_code = '''
digraph {
  rankdir=LR
  splines=ortho
  nodesep=0.6
  ranksep=1.2
  fontname=Helvetica

  node [fontname=Helvetica, fontsize=11]
  edge [fontname=Helvetica, fontsize=9, color="#555555"]

  subgraph cluster_sources {
    label="Source Nodes"
    style=filled
    fillcolor="#d5f5e3"

    "V0S0" [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S0\n(CustomStage)"]
    "ORA_Ext_Vehicle_Off_Road_Data" [shape=folder, fillcolor="#d5f5e3", style=filled, label="ORA_Ext_Vehicle_Off_Road_Data\n(OracleConnector)"]
  }

  subgraph cluster_lookups {
    label="Lookup Nodes"
    style=filled
    fillcolor="#fdebd0"

    "HF_SMR_VEHICLE_DIM" [shape=diamond, fillcolor="#fdebd0", style=filled, label="HF_SMR_VEHICLE_DIM\n(CHashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transform Nodes"
    style=filled
    fillcolor="#e8daef"

    "Tfm_LoadRecords" [shape=rectangle, fillcolor="#e8daef", style=filled, label="Tfm_LoadRecords\n(CTransformerStage)\nVehicle dimension matching using registration number\nData deduplication logic"]
    "V0S1" [shape=rectangle, fillcolor="#e8daef", style=filled, label="V0S1\n(CustomStage)"]
    "transactionManager" [shape=rectangle, fillcolor="#e8daef", style=filled, label="transactionManager\n(CustomStage)"]
    "RejectDataElements" [shape=rectangle, fillcolor="#e8daef", style=filled, label="RejectDataElements\n(CustomStage)"]
    "TrxOutput_V0S2P3" [shape=rectangle, fillcolor="#e8daef", style=filled, label="TrxOutput_V0S2P3\n(Transformer Output)"]
  }

  subgraph cluster_targets {
    label="Target Nodes"
    style=filled
    fillcolor="#d6eaf8"

    "V0S0P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S0P2\n(CustomOutput)"]
    "V116S0P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V116S0P2\n(HashedOutput)"]
    "TrxOutput_V0S2P2_V0S2P3" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="TrxOutput_V0S2P2_V0S2P3\n(Target Connector)"]
    "Load_VOR_Exception_File" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Load_VOR_Exception_File\n(SeqFileStage)"]
    "V0S1P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S1P2\n(OracleConnector)"]
    "Supp_VOR_Exception" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Supp_VOR_Exception\n(SeqFileStage)"]
  }

  "V0S0" -> "V0S0P2" [label="V0S0P2"]
  "ORA_Ext_Vehicle_Off_Road_Data" -> "Tfm_LoadRecords" [label="Lnk_Vehicle_off_Road_Data"]
  "HF_SMR_VEHICLE_DIM" -> "Tfm_LoadRecords" [label="lkVehicleDim_REg"]
  "Tfm_LoadRecords" -> "V116S0P2" [label="V0S2P7"]
  "Tfm_LoadRecords" -> "TrxOutput_V0S2P2_V0S2P3" [label="Load_HFVehicleoffRoad"]
  "Tfm_LoadRecords" -> "Load_VOR_Exception_File" [label="Load_VOR_Exception_File"]
  "Tfm_LoadRecords" -> "V0S1" [label="Load_StgVehicleoffRoad"]
  "V0S1" -> "transactionManager" [label="V0S1P2"]
  "transactionManager" -> "V0S1P2" [label="V0S1P2"]
  "V0S1P2" -> "RejectDataElements" [label="RejectDataElements"]
  "Load_VOR_Exception_File" -> "Supp_VOR_Exception" [label="V0S2"]
  "Load_VOR_Exception_File" -> "Supp_VOR_Exception" [label="V0S2P3"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph {
  rankdir=LR
  splines=ortho
  nodesep=0.6
  ranksep=1.2
  fontname=Helvetica

  node [fontname=Helvetica, fontsize=11]
  edge [fontname=Helvetica, fontsize=9, color="#555555"]

  subgraph cluster_sources {
    label="Source Nodes"
    style=filled
    fillcolor="#d5f5e3"

    "V0S0" [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S0\n(CustomStage)"]
    "ORA_Ext_Vehicle_Off_Road_Data" [shape=folder, fillcolor="#d5f5e3", style=filled, label="ORA_Ext_Vehicle_Off_Road_Data\n(OracleConnector)"]
  }

  subgraph cluster_lookups {
    label="Lookup Nodes"
    style=filled
    fillcolor="#fdebd0"

    "HF_SMR_VEHICLE_DIM" [shape=diamond, fillcolor="#fdebd0", style=filled, label="HF_SMR_VEHICLE_DIM\n(CHashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transform Nodes"
    style=filled
    fillcolor="#e8daef"

    "Tfm_LoadRecords" [shape=rectangle, fillcolor="#e8daef", style=filled, label="Tfm_LoadRecords\n(CTransformerStage)\nVehicle dimension matching using registration number\nData deduplication logic"]
    "V0S1" [shape=rectangle, fillcolor="#e8daef", style=filled, label="V0S1\n(CustomStage)"]
    "transactionManager" [shape=rectangle, fillcolor="#e8daef", style=filled, label="transactionManager\n(CustomStage)"]
    "RejectDataElements" [shape=rectangle, fillcolor="#e8daef", style=filled, label="RejectDataElements\n(CustomStage)"]
    "TrxOutput_V0S2P3" [shape=rectangle, fillcolor="#e8daef", style=filled, label="TrxOutput_V0S2P3\n(Transformer Output)"]
  }

  subgraph cluster_targets {
    label="Target Nodes"
    style=filled
    fillcolor="#d6eaf8"

    "V0S0P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S0P2\n(CustomOutput)"]
    "V116S0P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V116S0P2\n(HashedOutput)"]
    "TrxOutput_V0S2P2_V0S2P3" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="TrxOutput_V0S2P2_V0S2P3\n(Target Connector)"]
    "Load_VOR_Exception_File" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Load_VOR_Exception_File\n(SeqFileStage)"]
    "V0S1P2" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S1P2\n(OracleConnector)"]
    "Supp_VOR_Exception" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Supp_VOR_Exception\n(SeqFileStage)"]
  }

  "V0S0" -> "V0S0P2" [label="V0S0P2"]
  "ORA_Ext_Vehicle_Off_Road_Data" -> "Tfm_LoadRecords" [label="Lnk_Vehicle_off_Road_Data"]
  "HF_SMR_VEHICLE_DIM" -> "Tfm_LoadRecords" [label="lkVehicleDim_REg"]
  "Tfm_LoadRecords" -> "V116S0P2" [label="V0S2P7"]
  "Tfm_LoadRecords" -> "TrxOutput_V0S2P2_V0S2P3" [label="Load_HFVehicleoffRoad"]
  "Tfm_LoadRecords" -> "Load_VOR_Exception_File" [label="Load_VOR_Exception_File"]
  "Tfm_LoadRecords" -> "V0S1" [label="Load_StgVehicleoffRoad"]
  "V0S1" -> "transactionManager" [label="V0S1P2"]
  "transactionManager" -> "V0S1P2" [label="V0S1P2"]
  "V0S1P2" -> "RejectDataElements" [label="RejectDataElements"]
  "Load_VOR_Exception_File" -> "Supp_VOR_Exception" [label="V0S2"]
  "Load_VOR_Exception_File" -> "Supp_VOR_Exception" [label="V0S2P3"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph BusinessLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.8
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=2.0]
  edge [fontname=Helvetica fontsize=8 color="#888888"]

  subgraph cluster_sources {
    label="Data Sources"
    ORA_Ext_Vehicle_Off_Road_Data [shape=folder fillcolor="#d5f5e3" style=filled label="Vehicle Off Road Data\nOracle source\nRegistration-based matching"]
    V0S0 [shape=folder fillcolor="#d5f5e3" style=filled label="Custom Source\nData source"]
  }

  subgraph cluster_lookups {
    label="Reference Data"
    HF_SMR_VEHICLE_DIM [shape=diamond fillcolor="#fdebd0" style=filled label="Vehicle Dimension\nReference data"]
  }

  subgraph cluster_transforms {
    label="Processing"
    Tfm_LoadRecords [shape=box fillcolor="#e8daef" style=filled label="Load Records\nData transformer\nVehicle dimension matching"]
    V0S1 [shape=box fillcolor="#e8daef" style=filled label="Stage Processor\nData processing"]
    transactionManager [shape=box fillcolor="#e8daef" style=filled label="Transaction Manager\nData processing"]
    RejectDataElements [shape=box fillcolor="#e8daef" style=filled label="Reject Elements\nData processing"]
    TrxOutput_V0S2P3 [shape=box fillcolor="#e8daef" style=filled label="Output Processor\nData processing"]
  }

  subgraph cluster_targets {
    label="Destinations"
    V0S0P2 [shape=cylinder fillcolor="#d6eaf8" style=filled label="Custom Output\nData destination"]
    V116S0P2 [shape=cylinder fillcolor="#d6eaf8" style=filled label="Hashed Output\nData destination"]
    TrxOutput_V0S2P2_V0S2P3 [shape=cylinder fillcolor="#d6eaf8" style=filled label="Target Connector\nData destination"]
    Load_VOR_Exception_File [shape=cylinder fillcolor="#d6eaf8" style=filled label="Exception File\nData destination"]
    V0S1P2 [shape=cylinder fillcolor="#d6eaf8" style=filled label="Oracle Output\nData destination"]
    Supp_VOR_Exception [shape=cylinder fillcolor="#d6eaf8" style=filled label="Exception Suppression\nData destination"]
  }

  ORA_Ext_Vehicle_Off_Road_Data -> Tfm_LoadRecords [label="feeds" penwidth=2 color=black]
  HF_SMR_VEHICLE_DIM -> Tfm_LoadRecords [label="enriches with vehicle data" penwidth=2 color=black]
  Tfm_LoadRecords -> V116S0P2 [label="loads to warehouse" penwidth=2 color=black]
  Tfm_LoadRecords -> TrxOutput_V0S2P2_V0S2P3 [label="loads to warehouse" penwidth=2 color=black]
  Tfm_LoadRecords -> Load_VOR_Exception_File [label="loads to exception file" penwidth=2 color=black]
  Tfm_LoadRecords -> V0S1 [label="loads to stage" penwidth=2 color=black]
  V0S1 -> transactionManager [label="processes" penwidth=1]
  transactionManager -> V0S1P2 [label="processes" penwidth=1]
  V0S1P2 -> RejectDataElements [label="rejects elements" penwidth=1]
  Load_VOR_Exception_File -> Supp_VOR_Exception [label="suppresses exceptions" penwidth=1]
  V0S0 -> V0S0P2 [label="feeds" penwidth=1]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph DataLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.5
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=1.8]
  edge [fontname=Helvetica fontsize=8 color="#555555"]

  subgraph cluster_sources {
    label="Sources"
    ORA_Ext_Vehicle_Off_Road_Data [shape=folder, fillcolor="#d5f5e3", style=filled, label="ORA_Ext_Vehicle_Off_Road_Data\n(OracleConnector)"]
    V0S0 [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S0\n(CustomStage)"]
  }

  subgraph cluster_lookups {
    label="Lookups"
    HF_SMR_VEHICLE_DIM [shape=diamond, fillcolor="#fdebd0", style=filled, label="HF_SMR_VEHICLE_DIM\n(CHashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    Tfm_LoadRecords [shape=box, fillcolor="#e8daef", style=filled, label="Tfm_LoadRecords\n(CTransformerStage)\nVehicle dimension matching\nData deduplication logic"]
    V0S1 [shape=box, fillcolor="#e8daef", style=filled, label="V0S1\n(CustomStage)"]
    transactionManager [shape=box, fillcolor="#e8daef", style=filled, label="transactionManager\n(CustomStage)"]
    RejectDataElements [shape=box, fillcolor="#e8daef", style=filled, label="RejectDataElements\n(CustomStage)"]
    TrxOutput_V0S2P3 [shape=box, fillcolor="#e8daef", style=filled, label="TrxOutput_V0S2P3\n(Transformer Output)"]
  }

  subgraph cluster_targets {
    label="Targets"
    V0S0P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S0P2\n(CustomOutput)"]
    V116S0P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V116S0P2\n(HashedOutput)"]
    TrxOutput_V0S2P2_V0S2P3 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="TrxOutput_V0S2P2_V0S2P3\n(Target Connector)"]
    Load_VOR_Exception_File [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Load_VOR_Exception_File\n(SeqFileStage)"]
    V0S1P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S1P2\n(OracleConnector)"]
    Supp_VOR_Exception [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Supp_VOR_Exception\n(SeqFileStage)"]
  }

  V0S0 -> V0S0P2 [label="V0S0P2", penwidth=2, color=black]
  ORA_Ext_Vehicle_Off_Road_Data -> Tfm_LoadRecords [label="Lnk_Vehicle_off_Road_Data"]
  HF_SMR_VEHICLE_DIM -> Tfm_LoadRecords [label="lkVehicleDim_REg"]
  Tfm_LoadRecords -> V116S0P2 [label="V0S2P7"]
  Tfm_LoadRecords -> TrxOutput_V0S2P2_V0S2P3 [label="Load_HFVehicleoffRoad"]
  Tfm_LoadRecords -> Load_VOR_Exception_File [label="Load_VOR_Exception_File"]
  Tfm_LoadRecords -> V0S1 [label="Load_StgVehicleoffRoad"]
  V0S1 -> transactionManager [label="V0S1P2"]
  transactionManager -> V0S1P2 [label="V0S1P2"]
  V0S1P2 -> RejectDataElements [label="RejectDataElements"]
  Load_VOR_Exception_File -> Supp_VOR_Exception [label="V0S2 / V0S2P3"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph {
  rankdir=LR
  splines=ortho
  nodesep=0.6
  ranksep=1.2
  fontname=Helvetica

  node [fontname=Helvetica, fontsize=11]
  edge [fontname=Helvetica, fontsize=9, color="#555555"]

  subgraph cluster_lookups {
    label="Lookups"
    style=filled
    fillcolor="#fdebd0"
    HSH_MIDTERM_HIST [shape=diamond, fillcolor="#fdebd0", style=filled, label="HSH_MIDTERM_HIST\n(HashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    style=filled
    fillcolor="#e8daef"
    V0S213P4 [shape=rectangle, fillcolor="#e8daef", style=filled, label="V0S213P4\n(Hashed File Output)"]
  }

  subgraph cluster_targets {
    label="Targets"
    style=filled
    fillcolor="#d6eaf8"
    HashedOutput_V0S213P4 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="HashedOutput_V0S213P4\n(Hashed File Output)\nEMPLOYEE_CHANGE_CODE -> EMPLOYEE_CHANGE_CODE"]
  }

  HSH_MIDTERM_HIST -> V0S213P4 [label="V0S213P4"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph {
  rankdir=LR
  splines=ortho
  nodesep=0.6
  ranksep=1.2
  fontname=Helvetica

  node [fontname=Helvetica, fontsize=11]
  edge [fontname=Helvetica, fontsize=9, color="#555555"]

  subgraph cluster_lookups {
    label="Lookups"
    style=filled
    fillcolor="#fdebd0"
    HSH_MIDTERM_HIST [shape=diamond, fillcolor="#fdebd0", style=filled, label="HSH_MIDTERM_HIST\n(HashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    style=filled
    fillcolor="#e8daef"
    V0S213P4 [shape=rectangle, fillcolor="#e8daef", style=filled, label="V0S213P4\n(Hashed File Output)"]
  }

  subgraph cluster_targets {
    label="Targets"
    style=filled
    fillcolor="#d6eaf8"
    HashedOutput_V0S213P4 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="HashedOutput_V0S213P4\n(Hashed File Output)\nEMPLOYEE_CHANGE_CODE -> EMPLOYEE_CHANGE_CODE"]
  }

  HSH_MIDTERM_HIST -> V0S213P4 [label="V0S213P4"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph BusinessLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.8
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=2.0]
  edge [fontname=Helvetica fontsize=8 color="#888888"]

  subgraph cluster_targets {
    label="Destinations"
    "V0S213P4" [shape=cylinder fillcolor="#d6eaf8" style=filled label="Hashed Output\nData storage"]
  }
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph DataLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.5
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=1.8]
  edge [fontname=Helvetica fontsize=8 color="#555555"]

  subgraph cluster_targets {
    label="Targets"
    "V0S213P4" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S213P4\n(HashedOutput)"]
  }
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph BusinessLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.8
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=2.0]
  edge [fontname=Helvetica fontsize=8 color="#888888"]

  subgraph cluster_sources {
    label="Data Sources"
    ORA_Ext_Vehicle_Off_Road_Data [label="Vehicle Off Road Data\nOracle source\nRegistration-based matching" shape=folder fillcolor="#d5f5e3" style=filled]
    V0S0 [label="Custom Source\nData input" shape=folder fillcolor="#d5f5e3" style=filled]
  }

  subgraph cluster_lookups {
    label="Reference Data"
    HF_SMR_VEHICLE_DIM [label="Vehicle Dimension\nReference data" shape=diamond fillcolor="#fdebd0" style=filled]
  }

  subgraph cluster_transforms {
    label="Processing"
    Tfm_LoadRecords [label="Load Records\nData transformer\nVehicle dimension matching" shape=box fillcolor="#e8daef" style=filled]
    transactionManager [label="Transaction Manager\nData processing" shape=box fillcolor="#e8daef" style=filled]
    TrxOutput_V0S2P3 [label="Transformer Output\nData processing" shape=box fillcolor="#e8daef" style=filled]
  }

  subgraph cluster_targets {
    label="Destinations"
    V0S0P2 [label="Custom Output\nData output" shape=cylinder fillcolor="#d6eaf8" style=filled]
    V116S0P2 [label="Hashed Output\nData storage" shape=cylinder fillcolor="#d6eaf8" style=filled]
    TrxOutput_V0S2P2_V0S2P3 [label="Target Connector\nData destination" shape=cylinder fillcolor="#d6eaf8" style=filled]
    Load_VOR_Exception_File [label="Exception File\nException file" shape=cylinder fillcolor="#d6eaf8" style=filled]
    V0S1 [label="Staging Output\nData staging" shape=cylinder fillcolor="#d6eaf8" style=filled]
    V0S1P2 [label="Oracle Output\nData output" shape=cylinder fillcolor="#d6eaf8" style=filled]
    RejectDataElements [label="Rejected Elements\nData rejection" shape=cylinder fillcolor="#d6eaf8" style=filled]
    Supp_VOR_Exception [label="Supplementary Exception\nException file" shape=cylinder fillcolor="#d6eaf8" style=filled]
  }

  ORA_Ext_Vehicle_Off_Road_Data -> Tfm_LoadRecords [label="feeds" penwidth=2 color=black]
  HF_SMR_VEHICLE_DIM -> Tfm_LoadRecords [label="enriches with vehicle data" penwidth=2 color=black]
  Tfm_LoadRecords -> V116S0P2 [label="loads to warehouse" penwidth=2 color=black]
  Tfm_LoadRecords -> TrxOutput_V0S2P2_V0S2P3 [label="loads to warehouse" penwidth=2 color=black]
  Tfm_LoadRecords -> Load_VOR_Exception_File [label="loads to exception file" penwidth=2 color=black]
  Tfm_LoadRecords -> V0S1 [label="loads to staging" penwidth=2 color=black]
  V0S1 -> transactionManager [label="processes" penwidth=2 color=black]
  transactionManager -> V0S1P2 [label="processes" penwidth=2 color=black]
  V0S1P2 -> RejectDataElements [label="rejects" penwidth=2 color=black]
  Load_VOR_Exception_File -> Supp_VOR_Exception [label="supplements" penwidth=2 color=black]
  V0S0 -> V0S0P2 [label="feeds" penwidth=2 color=black]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph DataLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.5
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=1.8]
  edge [fontname=Helvetica fontsize=8 color="#555555"]

  subgraph cluster_sources {
    label="Sources"
    ORA_Ext_Vehicle_Off_Road_Data [shape=folder, fillcolor="#d5f5e3", style=filled, label="ORA_Ext_Vehicle_Off_Road_Data\n(OracleConnector)"]
    V0S0 [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S0\n(CustomStage)"]
  }

  subgraph cluster_lookups {
    label="Lookups"
    HF_SMR_VEHICLE_DIM [shape=diamond, fillcolor="#fdebd0", style=filled, label="HF_SMR_VEHICLE_DIM\n(CHashedFileStage)"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    Tfm_LoadRecords [shape=box, fillcolor="#e8daef", style=filled, label="Tfm_LoadRecords\n(CTransformerStage)\nVehicle dimension matching\nData deduplication logic"]
    TrxOutput_V0S2P3 [shape=box, fillcolor="#e8daef", style=filled, label="TrxOutput_V0S2P3\n(Transformer Output)"]
    transactionManager [shape=box, fillcolor="#e8daef", style=filled, label="transactionManager\n(CustomStage)"]
  }

  subgraph cluster_targets {
    label="Targets"
    V0S0P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S0P2\n(CustomOutput)"]
    V116S0P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V116S0P2\n(HashedOutput)"]
    TrxOutput_V0S2P2_V0S2P3 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="TrxOutput_V0S2P2_V0S2P3\n(Target Connector)"]
    Load_VOR_Exception_File [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Load_VOR_Exception_File\n(SeqFileStage)\nsvException = -1"]
    V0S1 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S1\n(CustomStage)"]
    V0S1P2 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="V0S1P2\n(OracleConnector)"]
    RejectDataElements [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="RejectDataElements\n(CustomStage)"]
    Supp_VOR_Exception [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Supp_VOR_Exception\n(SeqFileStage)"]
  }

  V0S0 -> V0S0P2 [label="V0S0P2", penwidth=2, color=black]
  ORA_Ext_Vehicle_Off_Road_Data -> Tfm_LoadRecords [label="Lnk_Vehicle_off_Road_Data", penwidth=2, color=black]
  HF_SMR_VEHICLE_DIM -> Tfm_LoadRecords [label="lkVehicleDim_REg", penwidth=2, color=black]
  Tfm_LoadRecords -> V116S0P2 [label="V0S2P7", penwidth=2, color=black]
  Tfm_LoadRecords -> TrxOutput_V0S2P2_V0S2P3 [label="Load_HFVehicleoffRoad", penwidth=2, color=black]
  Tfm_LoadRecords -> Load_VOR_Exception_File [label="Load_VOR_Exception_File", penwidth=2, color=black]
  Tfm_LoadRecords -> V0S1 [label="Load_StgVehicleoffRoad", penwidth=2, color=black]
  V0S1 -> transactionManager [label="V0S1P2"]
  transactionManager -> V0S1P2 [label="V0S1P2"]
  V0S1P2 -> RejectDataElements [label="RejectDataElements"]
  Load_VOR_Exception_File -> Supp_VOR_Exception [label="V0S2 / V0S2P3"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph DataLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.5
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=1.8]
  edge [fontname=Helvetica fontsize=8]

  subgraph cluster_sources {
    label="Sources"
    V0S0 [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S0\n(CustomStage)"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    V0S0P2 [shape=box, fillcolor="#e8daef", style=filled, label="V0S0P2\n(CustomOutput)"]
    ORA_Ext_Vehicle_Off_Road_Data [shape=box, fillcolor="#e8daef", style=filled, label="ORA_Ext_Vehicle_Off_Road_Data\n(OracleConnector)"]
    Tfm_LoadRecords [shape=box, fillcolor="#e8daef", style=filled, label="Tfm_LoadRecords\n(CTransformerStage)\nVehicle dimension matching\nData deduplication logic"]
    V116S0P2 [shape=box, fillcolor="#e8daef", style=filled, label="V116S0P2\n(HashedOutput)"]
    TrxOutput_V0S2P3 [shape=box, fillcolor="#e8daef", style=filled, label="TrxOutput_V0S2P3\n(Transformer Output)"]
    Load_VOR_Exception_File [shape=box, fillcolor="#e8daef", style=filled, label="Load_VOR_Exception_File\n(SeqFileStage)"]
    V0S1 [shape=box, fillcolor="#e8daef", style=filled, label="V0S1\n(CustomStage)"]
    transactionManager [shape=box, fillcolor="#e8daef", style=filled, label="transactionManager\n(CustomStage)"]
    V0S1P2 [shape=box, fillcolor="#e8daef", style=filled, label="V0S1P2\n(OracleConnector)"]
  }

  subgraph cluster_lookups {
    label="Lookups"
    HF_SMR_VEHICLE_DIM [shape=diamond, fillcolor="#fdebd0", style=filled, label="HF_SMR_VEHICLE_DIM\n(CHashedFileStage)"]
  }

  subgraph cluster_targets {
    label="Targets"
    TrxOutput_V0S2P2_V0S2P3 [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="TrxOutput_V0S2P2_V0S2P3\n(Target Connector)"]
    RejectDataElements [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="RejectDataElements\n(CustomStage)"]
    Supp_VOR_Exception [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="Supp_VOR_Exception\n(SeqFileStage)"]
  }

  V0S0 -> V0S0P2 [label="V0S0P2", color=black, penwidth=2.5]
  V0S0P2 -> ORA_Ext_Vehicle_Off_Road_Data [label="V0S0P2_Output", color=black, penwidth=2.5]
  ORA_Ext_Vehicle_Off_Road_Data -> Tfm_LoadRecords [label="Lnk_Vehicle_off_Road_Data", color=black, penwidth=2.5]
  HF_SMR_VEHICLE_DIM -> Tfm_LoadRecords [label="lkVehicleDim_REg", color="#e67e22", penwidth=1.0, style=dashed]
  Tfm_LoadRecords -> V116S0P2 [label="V0S2P7", color=black, penwidth=2.5]
  Tfm_LoadRecords -> Load_VOR_Exception_File [label="Load_VOR_Exception_File", color="#333333", penwidth=1.5]
  Tfm_LoadRecords -> V0S1 [label="Load_StgVehicleoffRoad", color="#333333", penwidth=1.5]
  Tfm_LoadRecords -> TrxOutput_V0S2P2_V0S2P3 [label="Load_HFVehicleoffRoad", color="#333333", penwidth=1.5]
  V0S1 -> transactionManager [label="V0S1P2", color="#333333", penwidth=1.5]
  transactionManager -> V0S1P2 [label="V0S1P2", color="#333333", penwidth=1.5]
  V0S1P2 -> RejectDataElements [label="3", color="#333333", penwidth=1.5]
  Load_VOR_Exception_File -> Supp_VOR_Exception [label="V0S2 / V0S2P3", color="#333333", penwidth=1.5]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph BusinessLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.8
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=2.0]
  edge [fontname=Helvetica fontsize=8]

  subgraph cluster_sources {
    label="Data Sources"
    "V0S0" [label="Custom Source\nData source" shape=folder fillcolor="#d5f5e3" style=filled]
  }

  subgraph cluster_lookups {
    label="Reference Data"
    "HF_SMR_VEHICLE_DIM" [label="Vehicle Dimension\nReference data" shape=diamond fillcolor="#fdebd0" style=filled]
  }

  subgraph cluster_transforms {
    label="Processing"
    "V0S0P2" [label="Custom Output\nData processor" shape=box fillcolor="#e8daef" style=filled]
    "ORA_Ext_Vehicle_Off_Road_Data" [label="Vehicle Off Road Data\nOracle source" shape=box fillcolor="#e8daef" style=filled]
    "Tfm_LoadRecords" [label="Load Records\nData transformer\nVehicle dimension matching" shape=box fillcolor="#e8daef" style=filled]
    "V116S0P2" [label="Hashed Output\nData processor" shape=box fillcolor="#e8daef" style=filled]
    "Load_VOR_Exception_File" [label="Exception File\nSequential file stage" shape=box fillcolor="#e8daef" style=filled]
    "V0S1" [label="Custom Stage\nData processor" shape=box fillcolor="#e8daef" style=filled]
    "transactionManager" [label="Transaction Manager\nData processor" shape=box fillcolor="#e8daef" style=filled]
  }

  subgraph cluster_targets {
    label="Destinations"
    "TrxOutput_V0S2P2_V0S2P3" [label="Output Connector\nTarget connector" shape=cylinder fillcolor="#d6eaf8" style=filled]
    "RejectDataElements" [label="Reject Data\nData target" shape=cylinder fillcolor="#d6eaf8" style=filled]
    "Supp_VOR_Exception" [label="Exception Support\nSequential file stage" shape=cylinder fillcolor="#d6eaf8" style=filled]
  }

  "V0S0" -> "V0S0P2" [label="feeds" color=black penwidth=2.5]
  "V0S0P2" -> "ORA_Ext_Vehicle_Off_Road_Data" [label="feeds" color=black penwidth=2.5]
  "ORA_Ext_Vehicle_Off_Road_Data" -> "Tfm_LoadRecords" [label="feeds" color=black penwidth=2.5]
  "HF_SMR_VEHICLE_DIM" -> "Tfm_LoadRecords" [label="reference data" color="#e67e22" penwidth=1.0 style=dashed]
  "Tfm_LoadRecords" -> "V116S0P2" [label="feeds" color=black penwidth=2.5]
  "Tfm_LoadRecords" -> "Load_VOR_Exception_File" [label="feeds" color="#555555" penwidth=1.5]
  "Tfm_LoadRecords" -> "V0S1" [label="feeds" color="#555555" penwidth=1.5]
  "Tfm_LoadRecords" -> "TrxOutput_V0S2P2_V0S2P3" [label="loads to warehouse" color="#555555" penwidth=1.5]
  "V0S1" -> "transactionManager" [label="feeds" color="#555555" penwidth=1.5]
  "transactionManager" -> "V0S1P2" [label="feeds" color="#555555" penwidth=1.5]
  "V0S1P2" -> "RejectDataElements" [label="feeds" color="#555555" penwidth=1.5]
  "Load_VOR_Exception_File" -> "Supp_VOR_Exception" [label="loads to warehouse" color="#555555" penwidth=1.5]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph DataLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.5
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=1.8]
  edge [fontname=Helvetica fontsize=8]

  subgraph cluster_sources {
    label="Sources"
    "lk_HSH_MIDTERM_HIST" [shape=folder, fillcolor="#d5f5e3", style=filled, label="lk_HSH_MIDTERM_HIST\n(HashedInput)"]
    "V0S213P4_original" [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S213P4_original"]
  }

  subgraph cluster_transforms {
    label="Transforms"
    "HSH_MIDTERM_HIST" [shape=box, fillcolor="#e8daef", style=filled, label="HSH_MIDTERM_HIST\n(HashedFileStage)"]
    "V0S213P4" [shape=box, fillcolor="#e8daef", style=filled, label="V0S213P4\n(Hashed File Output)\nEMPLOYEE_CHANGE_CODE -> EMPLOYEE_CHANGE_CODE\nBARCLAYS_EMPLOYEE_ACTION_SK -> BARCLAYS_EMPLOYEE_ACTION_SK"]
  }

  subgraph cluster_targets {
    label="Targets"
    "lk_XFM_HSH_MIDTERM_HIST" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="lk_XFM_HSH_MIDTERM_HIST\n(HashedOutput)"]
    "HashedOutput_V0S213P4" [shape=cylinder, fillcolor="#d6eaf8", style=filled, label="HashedOutput_V0S213P4\n(Hashed File Output)"]
  }

  subgraph cluster_isolated {
    label="Unconnected"
    style=dashed
    "V0S213P4_original" [shape=folder, fillcolor="#d5f5e3", style=filled, label="V0S213P4_original"]
  }

  "HSH_MIDTERM_HIST" -> "V0S213P4" [color=black, penwidth=2.5, label="V0S213P4"]
}
'''

graphviz.Source(dot_code)

# %%
import graphviz

dot_code = '''
digraph BusinessLineage {
  rankdir=LR
  splines=ortho
  nodesep=0.5
  ranksep=1.8
  fontname=Helvetica

  node [fontname=Helvetica fontsize=11 width=2.0]
  edge [fontname=Helvetica fontsize=8]

  subgraph cluster_transforms {
    label="Processing"
    "HSH_MIDTERM_HIST" [shape=box fillcolor="#e8daef" style=filled label="Midterm History\nData transformer"]
    "V0S213P4" [shape=box fillcolor="#e8daef" style=filled label="Hashed File Output\nData transformer"]
  }

  subgraph cluster_targets {
    label="Destinations"
    "HashedOutput_V0S213P4" [shape=cylinder fillcolor="#d6eaf8" style=filled label="Hashed Output\nData destination"]
  }

  "HSH_MIDTERM_HIST" -> "V0S213P4" [color=black penwidth=2.5 label="feeds"]
  "V0S213P4" -> "HashedOutput_V0S213P4" [color="#555555" penwidth=1.5 label="loads to warehouse"]
}
'''

graphviz.Source(dot_code)
